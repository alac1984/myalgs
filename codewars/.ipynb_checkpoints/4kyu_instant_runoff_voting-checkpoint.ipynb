# %%
# /kata/52996b5c99fdcb5f20000004/train/python
# This was FUCKING HARD, but I DID IT ALMOST ALONE! HELL YEAAAAAHHH!

from collections import defaultdict

def runoff(voters: list) -> str:
    count = defaultdict(int)
    # Create the list of candidates
    for candidate in voters[0]:
        count[candidate] = 0
        
    # Count the votes for first choice
    for voter in voters:
        count[voter[0]] += 1
    
    # from IPython.core.debugger import Pdb; Pdb().set_trace()
    # Check if there's just one candidate left
    if len(count.keys()) == 1:
        return voters[0][0]
    
    # Check for the complete tie possibility
    vote_count = set(count.values())
    if len(vote_count) == 1:
        return None
    
    # Initialize conditions
    max_votes = 0
    min_votes = 99999999999
    most_voted_group = []
    most_voted_draw = False
    least_voted_draw = False
    least_voted_group = []
    # Start counting
    
    for candidate, votes in count.items():
        # Check if is the highest vote score so far
        if votes > max_votes:
            max_votes = votes
            most_voted_draw = False
            most_voted_group = [candidate]
        # Check for draw on most voted
        if votes == max_votes and candidate not in most_voted_group:
            most_voted_draw = True
            most_voted_group.append(candidate)
        
        # Check if is the lowest vote score so far
        if votes < min_votes:
            min_votes = votes
            least_voted_draw = False
            least_voted_group = [candidate]
        # Check for draw on least voted
        if votes == min_votes and candidate not in least_voted_group:
            least_voted_draw = True
            least_voted_group.append(candidate)
            
    # If a candidate has more than half the votes, he wins
    if len(most_voted_group) == 1 and len(least_voted_group) == 0:
        return most_voted_group[0]
    else:
        # Remove least voted candidate from ballots
        new_voters = []
        for voter in voters:
            new_voter = [candidate for candidate in voter if candidate not in least_voted_group]
            new_voters.append(new_voter)
        # Run the function with the new ballots
        return runoff(new_voters)

# %%
import pytest
import ipytest
ipytest.autoconfig(magics=True)

# %%
# %%ipytest -qq
#
# def test_first_place_more_than_half_votes():
#     # The situation described
#     voters = [
#         ['a', 'b', 'c'],
#         ['a', 'c', 'b'],
#         ['b', 'a', 'c'],
#         ['a', 'b', 'c'],
#         ['a', 'c', 'b'],
#         ['a', 'b', 'c'],
#         ['b', 'a', 'c'],
#         ['c', 'b', 'a'],
#         ['a', 'c', 'b'],
#     ]
#
#     assert runoff(voters) == 'a'
#
# def test_draw_in_least_voted_remove_all_draw():
#     voters = [
#         ['dem', 'ind', 'rep'],
#         ['rep', 'ind', 'dem'],
#         ['ind', 'dem', 'rep'],
#         ['ind', 'rep', 'dem']
#     ]
#
#     assert runoff(voters) == 'ind'
#
# def test_complete_draw_possibility():
#     voters = [
#         ['a', 'c', 'd', 'e', 'b'],
#         ['e', 'b', 'd', 'c', 'a'],
#         ['d', 'e', 'c', 'a', 'b'],
#         ['c', 'e', 'd', 'b', 'a'],
#         ['b', 'e', 'a', 'c', 'd']
#     ]
#
#     assert runoff(voters) is None
# Out:
# FFF                                                                                          [100%]
# ============================================= FAILURES =============================================
# ______________________________ test_first_place_more_than_half_votes _______________________________
#
#     def test_first_place_more_than_half_votes():
#         # The situation described
#         voters = [
#             ['a', 'b', 'c'],
#             ['a', 'c', 'b'],
#             ['b', 'a', 'c'],
#             ['a', 'b', 'c'],
#             ['a', 'c', 'b'],
#             ['a', 'b', 'c'],
#             ['b', 'a', 'c'],
#             ['c', 'b', 'a'],
#             ['a', 'c', 'b'],
#         ]
#
# >       assert runoff(voters) == 'a'
#
# /tmp/ipykernel_16164/4148180544.py:15:
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
#
# voters = [['a', 'b', 'c'], ['a', 'c', 'b'], ['b', 'a', 'c'], ['a', 'b', 'c'], ['a', 'c', 'b'], ['a', 'b', 'c'], ...]
#
#     def runoff(voters: list) -> str:
#         count = defaultdict(int)
#         # Create the list of candidates
# >       for candidate in voters.keys():
# E       AttributeError: 'list' object has no attribute 'keys'
#
# /tmp/ipykernel_16164/3955367866.py:9: AttributeError
# _____________________________ test_draw_in_least_voted_remove_all_draw _____________________________
#
#     def test_draw_in_least_voted_remove_all_draw():
#         voters = [
#             ['dem', 'ind', 'rep'],
#             ['rep', 'ind', 'dem'],
#             ['ind', 'dem', 'rep'],
#             ['ind', 'rep', 'dem']
#         ]
#
# >       assert runoff(voters) == 'ind'
#
# /tmp/ipykernel_16164/4148180544.py:25:
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
#
# voters = [['dem', 'ind', 'rep'], ['rep', 'ind', 'dem'], ['ind', 'dem', 'rep'], ['ind', 'rep', 'dem']]
#
#     def runoff(voters: list) -> str:
#         count = defaultdict(int)
#         # Create the list of candidates
# >       for candidate in voters.keys():
# E       AttributeError: 'list' object has no attribute 'keys'
#
# /tmp/ipykernel_16164/3955367866.py:9: AttributeError
# __________________________________ test_complete_draw_possibility __________________________________
#
#     def test_complete_draw_possibility():
#         voters = [
#             ['a', 'c', 'd', 'e', 'b'],
#             ['e', 'b', 'd', 'c', 'a'],
#             ['d', 'e', 'c', 'a', 'b'],
#             ['c', 'e', 'd', 'b', 'a'],
#             ['b', 'e', 'a', 'c', 'd']
#         ]
#
# >       assert runoff(voters) is None
#
# /tmp/ipykernel_16164/4148180544.py:36:
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
#
# voters = [['a', 'c', 'd', 'e', 'b'], ['e', 'b', 'd', 'c', 'a'], ['d', 'e', 'c', 'a', 'b'], ['c', 'e', 'd', 'b', 'a'], ['b', 'e', 'a', 'c', 'd']]
#
#     def runoff(voters: list) -> str:
#         count = defaultdict(int)
#         # Create the list of candidates
# >       for candidate in voters.keys():
# E       AttributeError: 'list' object has no attribute 'keys'
#
# /tmp/ipykernel_16164/3955367866.py:9: AttributeError
# ===================================== short test summary info ======================================
# FAILED t_7588ca6b3d154e28a8dc9c0c14afc748.py::test_first_place_more_than_half_votes - AttributeError: 'list' object has no attribute 'keys'
# FAILED t_7588ca6b3d154e28a8dc9c0c14afc748.py::test_draw_in_least_voted_remove_all_draw - AttributeError: 'list' object has no attribute 'keys'
# FAILED t_7588ca6b3d154e28a8dc9c0c14afc748.py::test_complete_draw_possibility - AttributeError: 'list' object has no attribute 'keys'

# %%
voters = [
    ['a', 'c', 'b', 'd', 'e'],
    ['d', 'c', 'a', 'b', 'e'],
    ['e', 'b', 'd', 'a', 'c'],
    ['e', 'a', 'b', 'c', 'd'],
    ['b', 'c', 'e', 'a', 'd']
]

# a = 1, d = 1, e = 2, b = 1
# Will eliminate a, d and b, only e will survived and win

print(runoff(voters))
# Out:
# > /tmp/ipykernel_16164/351071123.py(14)runoff()
#      12     from IPython.core.debugger import Pdb; Pdb().set_trace()
#      13     # Check if there's just one candidate left
# ---> 14     if len(count.keys()) == 1:
#      15         return voters[0][0]
#      16
#
# ipdb> count
# defaultdict(<class 'int'>, {'a': 1, 'd': 1, 'e': 2, 'b': 1})
# ipdb> n
# > /tmp/ipykernel_16164/351071123.py(18)runoff()
#      16
#      17     # Check for the complete tie possibility
# ---> 18     vote_count = set(count.values())
#      19     if len(vote_count) == 1:
#      20         return None
#
# ipdb>
# > /tmp/ipykernel_16164/351071123.py(19)runoff()
#      17     # Check for the complete tie possibility
#      18     vote_count = set(count.values())
# ---> 19     if len(vote_count) == 1:
#      20         return None
#      21
#
# ipdb> n
# > /tmp/ipykernel_16164/351071123.py(23)runoff()
#      21
#      22     # Initialize conditions
# ---> 23     max_votes = 0
#      24     min_votes = 99999999999
#      25     most_voted_group = []
#
# ipdb> n
# > /tmp/ipykernel_16164/351071123.py(24)runoff()
#      22     # Initialize conditions
#      23     max_votes = 0
# ---> 24     min_votes = 99999999999
#      25     most_voted_group = []
#      26     most_voted_draw = False
#
# ipdb> n
# > /tmp/ipykernel_16164/351071123.py(25)runoff()
#      23     max_votes = 0
#      24     min_votes = 99999999999
# ---> 25     most_voted_group = []
#      26     most_voted_draw = False
#      27     least_voted_draw = False
#
# ipdb> n
# > /tmp/ipykernel_16164/351071123.py(26)runoff()
#      24     min_votes = 99999999999
#      25     most_voted_group = []
# ---> 26     most_voted_draw = False
#      27     least_voted_draw = False
#      28     least_voted_group = []
#
# ipdb> n
# > /tmp/ipykernel_16164/351071123.py(27)runoff()
#      25     most_voted_group = []
#      26     most_voted_draw = False
# ---> 27     least_voted_draw = False
#      28     least_voted_group = []
#      29     # Start counting
#
# ipdb> n
# > /tmp/ipykernel_16164/351071123.py(28)runoff()
#      26     most_voted_draw = False
#      27     least_voted_draw = False
# ---> 28     least_voted_group = []
#      29     # Start counting
#      30
#
# ipdb> n
# > /tmp/ipykernel_16164/351071123.py(31)runoff()
#      29     # Start counting
#      30
# ---> 31     for candidate, votes in count.items():
#      32         # Check if is the highest vote score so far
#      33         if votes > max_votes:
#
# ipdb> n
# > /tmp/ipykernel_16164/351071123.py(33)runoff()
#      31     for candidate, votes in count.items():
#      32         # Check if is the highest vote score so far
# ---> 33         if votes > max_votes:
#      34             max_votes = votes
#      35             most_voted_draw = False
#
# ipdb> candidate
# 'a'
# ipdb> votes
# 1
# ipdb> n
# > /tmp/ipykernel_16164/351071123.py(34)runoff()
#      32         # Check if is the highest vote score so far
#      33         if votes > max_votes:
# ---> 34             max_votes = votes
#      35             most_voted_draw = False
#      36             most_voted_group = [candidate]
#
# ipdb> n
# > /tmp/ipykernel_16164/351071123.py(35)runoff()
#      33         if votes > max_votes:
#      34             max_votes = votes
# ---> 35             most_voted_draw = False
#      36             most_voted_group = [candidate]
#      37         # Check for draw on most voted
# ipdb> n
# > /tmp/ipykernel_16164/351071123.py(36)runoff()
#      34             max_votes = votes
#      35             most_voted_draw = False
# ---> 36             most_voted_group = [candidate]
#      37         # Check for draw on most voted
#      38         if votes == max_votes and candidate not in most_voted_group:
#
# ipdb> n
# > /tmp/ipykernel_16164/351071123.py(38)runoff()
#      36             most_voted_group = [candidate]
#      37         # Check for draw on most voted
# ---> 38         if votes == max_votes and candidate not in most_voted_group:
#      39             most_voted_draw = True
#      40             most_voted_group.append(candidate)
#
# ipdb> n
# > /tmp/ipykernel_16164/351071123.py(43)runoff()
#      41
#      42         # Check if is the lowest vote score so far
# ---> 43         if votes < min_votes:
#      44             min_votes = votes
#      45             least_voted_draw = False
#
# ipdb> n
# > /tmp/ipykernel_16164/351071123.py(44)runoff()
#      42         # Check if is the lowest vote score so far
#      43         if votes < min_votes:
# ---> 44             min_votes = votes
#      45             least_voted_draw = False
#      46             least_voted_group = [candidate]
#
# ipdb> n
# > /tmp/ipykernel_16164/351071123.py(45)runoff()
#      43         if votes < min_votes:
#      44             min_votes = votes
# ---> 45             least_voted_draw = False
#      46             least_voted_group = [candidate]
#      47         # Check for draw on least voted
#
# ipdb> n
# > /tmp/ipykernel_16164/351071123.py(46)runoff()
#      44             min_votes = votes
#      45             least_voted_draw = False
# ---> 46             least_voted_group = [candidate]
#      47         # Check for draw on least voted
#      48         if votes == min_votes and candidate not in least_voted_group:
#
# ipdb> n
# > /tmp/ipykernel_16164/351071123.py(48)runoff()
#      46             least_voted_group = [candidate]
#      47         # Check for draw on least voted
# ---> 48         if votes == min_votes and candidate not in least_voted_group:
#      49             least_voted_draw = True
#      50             least_voted_group.append(candidate)
#
# ipdb> n
# > /tmp/ipykernel_16164/351071123.py(31)runoff()
#      29     # Start counting
#      30
# ---> 31     for candidate, votes in count.items():
#      32         # Check if is the highest vote score so far
#      33         if votes > max_votes:
#
# ipdb> n
# > /tmp/ipykernel_16164/351071123.py(33)runoff()
#      31     for candidate, votes in count.items():
#      32         # Check if is the highest vote score so far
# ---> 33         if votes > max_votes:
#      34             max_votes = votes
#      35             most_voted_draw = False
#
# ipdb> candidate
# 'd'
# ipdb> n
# > /tmp/ipykernel_16164/351071123.py(38)runoff()
#      36             most_voted_group = [candidate]
#      37         # Check for draw on most voted
# ---> 38         if votes == max_votes and candidate not in most_voted_group:
#      39             most_voted_draw = True
#      40             most_voted_group.append(candidate)
#
# ipdb> n
# > /tmp/ipykernel_16164/351071123.py(39)runoff()
#      37         # Check for draw on most voted
#      38         if votes == max_votes and candidate not in most_voted_group:
# ---> 39             most_voted_draw = True
#      40             most_voted_group.append(candidate)
#      41
# ipdb> n
# > /tmp/ipykernel_16164/351071123.py(40)runoff()
#      38         if votes == max_votes and candidate not in most_voted_group:
#      39             most_voted_draw = True
# ---> 40             most_voted_group.append(candidate)
#      41
#      42         # Check if is the lowest vote score so far
#
# ipdb> n
# > /tmp/ipykernel_16164/351071123.py(43)runoff()
#      41
#      42         # Check if is the lowest vote score so far
# ---> 43         if votes < min_votes:
#      44             min_votes = votes
#      45             least_voted_draw = False
#
# ipdb> most_voted_group
# ['a', 'd']
# ipdb> n
# > /tmp/ipykernel_16164/351071123.py(48)runoff()
#      46             least_voted_group = [candidate]
#      47         # Check for draw on least voted
# ---> 48         if votes == min_votes and candidate not in least_voted_group:
#      49             least_voted_draw = True
#      50             least_voted_group.append(candidate)
#
# ipdb> n
# > /tmp/ipykernel_16164/351071123.py(49)runoff()
#      47         # Check for draw on least voted
#      48         if votes == min_votes and candidate not in least_voted_group:
# ---> 49             least_voted_draw = True
#      50             least_voted_group.append(candidate)
#      51
#
# ipdb> n
# > /tmp/ipykernel_16164/351071123.py(50)runoff()
#      48         if votes == min_votes and candidate not in least_voted_group:
#      49             least_voted_draw = True
# ---> 50             least_voted_group.append(candidate)
#      51
#      52     # If a candidate has more than half the votes, he wins
#
# ipdb> n
# > /tmp/ipykernel_16164/351071123.py(31)runoff()
#      29     # Start counting
#      30
# ---> 31     for candidate, votes in count.items():
#      32         # Check if is the highest vote score so far
#      33         if votes > max_votes:
#
# ipdb> candidate
# 'd'
# ipdb> count
# defaultdict(<class 'int'>, {'a': 1, 'd': 1, 'e': 2, 'b': 1})
# ipdb> n
# > /tmp/ipykernel_16164/351071123.py(33)runoff()
#      31     for candidate, votes in count.items():
#      32         # Check if is the highest vote score so far
# ---> 33         if votes > max_votes:
#      34             max_votes = votes
#      35             most_voted_draw = False
#
# ipdb> candidate
# 'e'
# ipdb> votes
# 2
# ipdb> max_votes
# 1
# ipdb> n
# > /tmp/ipykernel_16164/351071123.py(34)runoff()
#      32         # Check if is the highest vote score so far
#      33         if votes > max_votes:
# ---> 34             max_votes = votes
#      35             most_voted_draw = False
#      36             most_voted_group = [candidate]
#
# ipdb> n
# > /tmp/ipykernel_16164/351071123.py(35)runoff()
#      33         if votes > max_votes:
#      34             max_votes = votes
# ---> 35             most_voted_draw = False
#      36             most_voted_group = [candidate]
#      37         # Check for draw on most voted
#
# ipdb> max_votes
# 2
# ipdb> n
# > /tmp/ipykernel_16164/351071123.py(36)runoff()
#      34             max_votes = votes
#      35             most_voted_draw = False
# ---> 36             most_voted_group = [candidate]
#      37         # Check for draw on most voted
#      38         if votes == max_votes and candidate not in most_voted_group:
#
# ipdb> n
# > /tmp/ipykernel_16164/351071123.py(38)runoff()
#      36             most_voted_group = [candidate]
#      37         # Check for draw on most voted
# ---> 38         if votes == max_votes and candidate not in most_voted_group:
#      39             most_voted_draw = True
#      40             most_voted_group.append(candidate)
# ipdb> most_voted_group
# ['e']
# ipdb> n
# > /tmp/ipykernel_16164/351071123.py(43)runoff()
#      41
#      42         # Check if is the lowest vote score so far
# ---> 43         if votes < min_votes:
#      44             min_votes = votes
#      45             least_voted_draw = False
#
# ipdb> votes
# 2
# ipdb> min_votes
# 1
# ipdb> n
# > /tmp/ipykernel_16164/351071123.py(48)runoff()
#      46             least_voted_group = [candidate]
#      47         # Check for draw on least voted
# ---> 48         if votes == min_votes and candidate not in least_voted_group:
#      49             least_voted_draw = True
#      50             least_voted_group.append(candidate)
#
# ipdb> votes
# 2
# ipdb> min_votes
# 1
# ipdb> most_voted_group
# ['e']
# ipdb> max_votes
# 2
# ipdb> least_voted_group
# ['a', 'd']
# ipdb> min_votes
# 1
# ipdb> most_voted_draw
# False
# ipdb> least_voted_draw
# True
# ipdb> n
# > /tmp/ipykernel_16164/351071123.py(31)runoff()
#      29     # Start counting
#      30
# ---> 31     for candidate, votes in count.items():
#      32         # Check if is the highest vote score so far
#      33         if votes > max_votes:
#
# ipdb> n
# > /tmp/ipykernel_16164/351071123.py(33)runoff()
#      31     for candidate, votes in count.items():
#      32         # Check if is the highest vote score so far
# ---> 33         if votes > max_votes:
#      34             max_votes = votes
#      35             most_voted_draw = False
#
# ipdb> candidate
# 'b'
# ipdb> q
